# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# create a dataframe and initial data preprocessing
df_weather = pd.read_csv("weather.csv", encoding = "ISO-8859-1")
display(df_weather.head())
# checking the dimensions of our dataframe
df_weather.shape
# we are working with 175 rows and 22 columns
# checking for duplicates
no_of_duplicates = df_weather.duplicated().sum()
print(f"The number of duplicates in the our raw data is {no_of_duplicates}")
# checking for missing values
missing_values_per_column = df_weather.isnull().sum()
print(missing_values_per_column)
# we can see that the Evaporation(MM), sunshine(hours), 9m cloud amount and 3 pm cloud amount are completely missing in the data
#imputing such a large number of data will lead to false precision and will introduce unnecessary noise . 
# we feel it is better to drop these values and work with the real data we have
df_weather = df_weather.drop(columns=["Evaporation (mm)", "Sunshine (hours)", "9am cloud amount (oktas)", "3pm cloud amount (oktas)" ], axis=1)
df_weather.isnull().sum()
# we still have some missing values , checking to see which row/rows do they belong do 
missing_values_row = df_weather.isnull().any(axis=1)
print(df_weather[missing_values_row])
# all the missing values belong to one row , decided to delete that data
df_weather = df_weather.dropna()
# verifying the 
df_weather.isnull().sum()
display(df_weather.head(20))
# Out:
#                              Location       Date  Minimum temperature (°C)  \
# 0  Melbourne (Olympic Park), Victoria  1/11/2022                       8.5
# 1  Melbourne (Olympic Park), Victoria  2/11/2022                       6.9
# 2  Melbourne (Olympic Park), Victoria  3/11/2022                       9.1
# 3  Melbourne (Olympic Park), Victoria  4/11/2022                      10.2
# 4  Melbourne (Olympic Park), Victoria  5/11/2022                      11.8
#
#    Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 0                      13.3            3.0               NaN
# 1                      15.7            2.8               NaN
# 2                      15.4            0.4               NaN
# 3                      17.8            0.2               NaN
# 4                      22.7            0.0               NaN
#
#    Sunshine (hours) Direction of maximum wind gust   \
# 0               NaN                              SW
# 1               NaN                             SSW
# 2               NaN                             SSW
# 3               NaN                               S
# 4               NaN                               N
#
#    Speed of maximum wind gust (km/h) Time of maximum wind gust  ...  \
# 0                               44.0                     11:36  ...
# 1                               43.0                     11:33  ...
# 2                               31.0                      8:07  ...
# 3                               24.0                     14:50  ...
# 4                               31.0                     11:58  ...
#
#    9am cloud amount (oktas)  9am wind direction  9am wind speed (km/h)  \
# 0                       NaN                  NW                     13
# 1                       NaN                   W                      9
# 2                       NaN                 SSW                      9
# 3                       NaN                 WSW                      6
# 4                       NaN                   N                      9
#
#   9am MSL pressure (hPa) 3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                  991.3                 13.2                       59.0
# 1                 1006.7                 15.1                       54.0
# 2                 1019.2                 13.8                       67.0
# 3                 1028.1                 16.9                       56.0
# 4                 1026.3                 18.8                       65.0
#
#    3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                       NaN                 WNW                   11.0
# 1                       NaN                 SSW                   13.0
# 2                       NaN                 SSW                    9.0
# 3                       NaN                  SW                    9.0
# 4                       NaN                  SW                   11.0
#
#   3pm MSL pressure (hPa)
# 0                  991.5
# 1                 1008.4
# 2                 1021.3
# 3                 1026.6
# 4                 1023.2
#
# [5 rows x 22 columns]
# The number of duplicates in the our raw data is 0
# Location                               0
# Date                                   0
# Minimum temperature (°C)               0
# Maximum temperature (°C)               1
# Rainfall (mm)                          0
# Evaporation (mm)                     175
# Sunshine (hours)                     175
# Direction of maximum wind gust         1
# Speed of maximum wind gust (km/h)      1
# Time of maximum wind gust              1
# 9am Temperature (°C)                   0
# 9am relative humidity (%)              0
# 9am cloud amount (oktas)             175
# 9am wind direction                     0
# 9am wind speed (km/h)                  0
# 9am MSL pressure (hPa)                 0
# 3pm Temperature (°C)                   1
# 3pm relative humidity (%)              1
# 3pm cloud amount (oktas)             175
# 3pm wind direction                     1
# 3pm wind speed (km/h)                  1
# 3pm MSL pressure (hPa)                 1
# dtype: int64
#                                Location        Date  Minimum temperature (°C)  \
# 174  Melbourne (Olympic Park), Victoria  24/04/2023                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm) Direction of maximum wind gust   \
# 174                       NaN            0.0                             NaN
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# 174                                NaN                       NaN
#
#      9am Temperature (°C)  9am relative humidity (%) 9am wind direction  \
# 174                  14.3                         87                 NE
#
#     9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 174                     9                  1032.5                   NaN
#
#      3pm relative humidity (%) 3pm wind direction  3pm wind speed (km/h)  \
# 174                        NaN                NaN                    NaN
#
#      3pm MSL pressure (hPa)
# 174                     NaN
#                               Location        Date  Minimum temperature (°C)  \
# 0   Melbourne (Olympic Park), Victoria   1/11/2022                       8.5
# 1   Melbourne (Olympic Park), Victoria   2/11/2022                       6.9
# 2   Melbourne (Olympic Park), Victoria   3/11/2022                       9.1
# 3   Melbourne (Olympic Park), Victoria   4/11/2022                      10.2
# 4   Melbourne (Olympic Park), Victoria   5/11/2022                      11.8
# 5   Melbourne (Olympic Park), Victoria   6/11/2022                      11.6
# 6   Melbourne (Olympic Park), Victoria   7/11/2022                      13.9
# 7   Melbourne (Olympic Park), Victoria   8/11/2022                      14.6
# 8   Melbourne (Olympic Park), Victoria   9/11/2022                      15.6
# 9   Melbourne (Olympic Park), Victoria  10/11/2022                      19.8
# 10  Melbourne (Olympic Park), Victoria  11/11/2022                      18.7
# 11  Melbourne (Olympic Park), Victoria  12/11/2022                      14.2
# 12  Melbourne (Olympic Park), Victoria  13/11/2022                      15.4
# 13  Melbourne (Olympic Park), Victoria  14/11/2022                      13.0
# 14  Melbourne (Olympic Park), Victoria  15/11/2022                       8.0
# 15  Melbourne (Olympic Park), Victoria  16/11/2022                       7.2
# 16  Melbourne (Olympic Park), Victoria  17/11/2022                       9.6
# 17  Melbourne (Olympic Park), Victoria  18/11/2022                       7.2
# 18  Melbourne (Olympic Park), Victoria  19/11/2022                      12.5
# 19  Melbourne (Olympic Park), Victoria  20/11/2022                      11.8
#
#     Maximum temperature (°C)  Rainfall (mm) Direction of maximum wind gust   \
# 0                       13.3            3.0                              SW
# 1                       15.7            2.8                             SSW
# 2                       15.4            0.4                             SSW
# 3                       17.8            0.2                               S
# 4                       22.7            0.0                               N
# 5                       27.1            0.0                             NNW
# 6                       25.9            0.0                               W
# 7                       27.6            0.0                             NNW
# 8                       29.3            2.8                             NNE
# 9                       26.4            0.0                             NNW
# 10                      20.2            3.0                             SSW
# 11                      19.3            0.0                             SSW
# 12                      24.8            6.6                               N
# 13                      17.4           13.6                             SSW
# 14                      13.1           14.2                              SW
# 15                      14.8            0.6                               S
# 16                      16.3            3.2                             SSW
# 17                      24.5            0.0                             NNW
# 18                      22.3            0.0                               N
# 19                      20.6           16.0                             NNW
#
#     Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# 0                                44.0                     11:36
# 1                                43.0                     11:33
# 2                                31.0                      8:07
# 3                                24.0                     14:50
# 4                                31.0                     11:58
# 5                                33.0                     18:43
# 6                                24.0                     13:42
# 7                                35.0                     11:24
# 8                                35.0                     12:24
# 9                                54.0                      9:58
# 10                               30.0                     12:38
# 11                               26.0                     12:58
# 12                               44.0                      9:34
# 13                               41.0                     12:56
# 14                               43.0                     11:45
# 15                               43.0                     14:47
# 16                               33.0                      0:35
# 17                               28.0                     15:26
# 18                               59.0                     17:16
# 19                               50.0                     15:42
#
#     9am Temperature (°C)  9am relative humidity (%) 9am wind direction  \
# 0                   12.0                         64                 NW
# 1                   11.0                         65                  W
# 2                   11.5                         70                SSW
# 3                   12.3                         84                WSW
# 4                   14.0                         78                  N
# 5                   17.9                         63                NNE
# 6                   19.7                         64                 NE
# 7                   21.8                         57                  N
# 8                   20.8                         67                  N
# 9                   23.8                         50                  N
# 10                  18.7                         80                SSW
# 11                  15.7                         69                SSE
# 12                  19.1                         88                NNE
# 13                  15.3                         78                  N
# 14                  10.1                         72                  W
# 15                  11.0                         64                WSW
# 16                  13.1                         71                SSW
# 17                  12.5                         70                 NE
# 18                  19.3                         52                 NE
# 19                  14.3                         63                 NW
#
#    9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                     13                   991.3                  13.2
# 1                      9                  1006.7                  15.1
# 2                      9                  1019.2                  13.8
# 3                      6                  1028.1                  16.9
# 4                      9                  1026.3                  18.8
# 5                      9                  1023.2                  26.2
# 6                      4                  1021.1                  20.2
# 7                     15                  1018.2                  25.8
# 8                     13                  1018.8                  28.3
# 9                     17                  1013.8                  25.1
# 10                    11                  1011.0                  18.2
# 11                     7                  1014.3                  17.6
# 12                     9                  1001.8                  24.3
# 13                    13                   997.1                  15.0
# 14                     7                  1013.1                  10.8
# 15                    11                  1015.1                  13.9
# 16                    13                  1019.3                  15.5
# 17                     7                  1016.6                  22.0
# 18                     9                  1003.1                  18.3
# 19                    15                   998.2                  19.4
#
#     3pm relative humidity (%) 3pm wind direction  3pm wind speed (km/h)  \
# 0                        59.0                WNW                   11.0
# 1                        54.0                SSW                   13.0
# 2                        67.0                SSW                    9.0
# 3                        56.0                 SW                    9.0
# 4                        65.0                 SW                   11.0
# 5                        33.0                 NW                    4.0
# 6                        66.0                WSW                    9.0
# 7                        43.0                 SW                    6.0
# 8                        37.0                NNW                   13.0
# 9                        44.0                NNW                   20.0
# 10                       81.0                SSW                   15.0
# 11                       66.0                SSW                   13.0
# 12                       59.0                  N                   19.0
# 13                       87.0                SSW                   13.0
# 14                       72.0                  S                   17.0
# 15                       51.0                  S                   15.0
# 16                       63.0                SSW                   13.0
# 17                       47.0                WSW                   11.0
# 18                       65.0                  N                   19.0
# 19                       36.0                WNW                   15.0
#
#     3pm MSL pressure (hPa)
# 0                    991.5
# 1                   1008.4
# 2                   1021.3
# 3                   1026.6
# 4                   1023.2
# 5                   1019.9
# 6                   1019.1
# 7                   1015.9
# 8                   1015.4
# 9                   1011.7
# 10                  1010.4
# 11                  1010.9
# 12                   998.6
# 13                  1003.6
# 14                  1013.1
# 15                  1015.9
# 16                  1018.7
# 17                  1010.9
# 18                   997.6
# 19                   997.1

# %%
# Looking at the data further shows that the values in the location column are all the same one location
df_weather = df_weather.drop(columns="Location")

# %%
df_weather
# Out:
#            Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0     1/11/2022                       8.5                      13.3
# 1     2/11/2022                       6.9                      15.7
# 2     3/11/2022                       9.1                      15.4
# 3     4/11/2022                      10.2                      17.8
# 4     5/11/2022                      11.8                      22.7
# ..          ...                       ...                       ...
# 169  19/04/2023                      14.4                      17.5
# 170  20/04/2023                       7.8                      18.5
# 171  21/04/2023                      11.3                      19.0
# 172  22/04/2023                      14.6                      19.2
# 173  23/04/2023                      14.8                      19.0
#
#      Rainfall (mm) Direction of maximum wind gust   \
# 0              3.0                              SW
# 1              2.8                             SSW
# 2              0.4                             SSW
# 3              0.2                               S
# 4              0.0                               N
# ..             ...                             ...
# 169            1.2                              SW
# 170            0.0                             SSW
# 171            0.0                             SSW
# 172            0.0                             SSW
# 173            0.0                             SSW
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# 0                                 44.0                     11:36
# 1                                 43.0                     11:33
# 2                                 31.0                      8:07
# 3                                 24.0                     14:50
# 4                                 31.0                     11:58
# ..                                 ...                       ...
# 169                               28.0                     11:32
# 170                               17.0                     12:47
# 171                               13.0                     10:48
# 172                               22.0                     16:09
# 173                               26.0                     15:45
#
#      9am Temperature (°C)  9am relative humidity (%) 9am wind direction  \
# 0                    12.0                         64                 NW
# 1                    11.0                         65                  W
# 2                    11.5                         70                SSW
# 3                    12.3                         84                WSW
# 4                    14.0                         78                  N
# ..                    ...                        ...                ...
# 169                  14.8                         66                WSW
# 170                  12.4                         72                NNE
# 171                  14.8                         78                 NE
# 172                  15.2                         84                 SW
# 173                  16.7                         79                SSE
#
#     9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                      13                   991.3                  13.2
# 1                       9                  1006.7                  15.1
# 2                       9                  1019.2                  13.8
# 3                       6                  1028.1                  16.9
# 4                       9                  1026.3                  18.8
# ..                    ...                     ...                   ...
# 169                     9                  1022.0                  15.8
# 170                     7                  1026.8                  17.5
# 171                     6                  1030.5                  18.6
# 172                     6                  1031.9                  18.8
# 173                     7                  1034.4                  17.8
#
#      3pm relative humidity (%) 3pm wind direction  3pm wind speed (km/h)  \
# 0                         59.0                WNW                   11.0
# 1                         54.0                SSW                   13.0
# 2                         67.0                SSW                    9.0
# 3                         56.0                 SW                    9.0
# 4                         65.0                 SW                   11.0
# ..                         ...                ...                    ...
# 169                       53.0                SSW                    9.0
# 170                       58.0                 SW                    4.0
# 171                       64.0                SSE                    2.0
# 172                       64.0                SSW                   11.0
# 173                       71.0                SSW                   13.0
#
#      3pm MSL pressure (hPa)
# 0                     991.5
# 1                    1008.4
# 2                    1021.3
# 3                    1026.6
# 4                    1023.2
# ..                      ...
# 169                  1022.1
# 170                  1025.5
# 171                  1029.2
# 172                  1029.7
# 173                  1032.4
#
# [174 rows x 17 columns]

# %%
# setting date column as index (will help with corss referencing witht the demand csv)
df_weather.set_index("Date", inplace=True)

# %%
# checking the datatypes 
df_weather.dtypes
# visual inspection of the columns suggests 9 am wind speed  int datatypes
df_weather['9am wind speed (km/h)'] = pd.to_numeric(df_weather['9am wind speed (km/h)'], errors='coerce')
df_weather.dtypes
# Out:
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Direction of maximum wind gust        object
# Speed of maximum wind gust (km/h)    float64
# Time of maximum wind gust             object
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)              int64
# 9am wind direction                    object
# 9am wind speed (km/h)                float64
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)            float64
# 3pm wind direction                    object
# 3pm wind speed (km/h)                float64
# 3pm MSL pressure (hPa)               float64
# dtype: object

# %%
df_weather.index = pd.to_datetime(df_weather.index, format="mixed", dayfirst=True)

# %%
df_weather.index.dtype
df_weather
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                       8.5                      13.3            3.0
# 2022-11-02                       6.9                      15.7            2.8
# 2022-11-03                       9.1                      15.4            0.4
# 2022-11-04                      10.2                      17.8            0.2
# 2022-11-05                      11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 2023-04-19                      14.4                      17.5            1.2
# 2023-04-20                       7.8                      18.5            0.0
# 2023-04-21                      11.3                      19.0            0.0
# 2023-04-22                      14.6                      19.2            0.0
# 2023-04-23                      14.8                      19.0            0.0
#
#            Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# Date
# 2022-11-01                              SW                               44.0
# 2022-11-02                             SSW                               43.0
# 2022-11-03                             SSW                               31.0
# 2022-11-04                               S                               24.0
# 2022-11-05                               N                               31.0
# ...                                    ...                                ...
# 2023-04-19                              SW                               28.0
# 2023-04-20                             SSW                               17.0
# 2023-04-21                             SSW                               13.0
# 2023-04-22                             SSW                               22.0
# 2023-04-23                             SSW                               26.0
#
#            Time of maximum wind gust  9am Temperature (°C)  \
# Date
# 2022-11-01                     11:36                  12.0
# 2022-11-02                     11:33                  11.0
# 2022-11-03                      8:07                  11.5
# 2022-11-04                     14:50                  12.3
# 2022-11-05                     11:58                  14.0
# ...                              ...                   ...
# 2023-04-19                     11:32                  14.8
# 2023-04-20                     12:47                  12.4
# 2023-04-21                     10:48                  14.8
# 2023-04-22                     16:09                  15.2
# 2023-04-23                     15:45                  16.7
#
#             9am relative humidity (%) 9am wind direction  \
# Date
# 2022-11-01                         64                 NW
# 2022-11-02                         65                  W
# 2022-11-03                         70                SSW
# 2022-11-04                         84                WSW
# 2022-11-05                         78                  N
# ...                               ...                ...
# 2023-04-19                         66                WSW
# 2023-04-20                         72                NNE
# 2023-04-21                         78                 NE
# 2023-04-22                         84                 SW
# 2023-04-23                         79                SSE
#
#             9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                   13.0                   991.3
# 2022-11-02                    9.0                  1006.7
# 2022-11-03                    9.0                  1019.2
# 2022-11-04                    6.0                  1028.1
# 2022-11-05                    9.0                  1026.3
# ...                           ...                     ...
# 2023-04-19                    9.0                  1022.0
# 2023-04-20                    7.0                  1026.8
# 2023-04-21                    6.0                  1030.5
# 2023-04-22                    6.0                  1031.9
# 2023-04-23                    7.0                  1034.4
#
#             3pm Temperature (°C)  3pm relative humidity (%)  \
# Date
# 2022-11-01                  13.2                       59.0
# 2022-11-02                  15.1                       54.0
# 2022-11-03                  13.8                       67.0
# 2022-11-04                  16.9                       56.0
# 2022-11-05                  18.8                       65.0
# ...                          ...                        ...
# 2023-04-19                  15.8                       53.0
# 2023-04-20                  17.5                       58.0
# 2023-04-21                  18.6                       64.0
# 2023-04-22                  18.8                       64.0
# 2023-04-23                  17.8                       71.0
#
#            3pm wind direction  3pm wind speed (km/h)  3pm MSL pressure (hPa)
# Date
# 2022-11-01                WNW                   11.0                   991.5
# 2022-11-02                SSW                   13.0                  1008.4
# 2022-11-03                SSW                    9.0                  1021.3
# 2022-11-04                 SW                    9.0                  1026.6
# 2022-11-05                 SW                   11.0                  1023.2
# ...                       ...                    ...                     ...
# 2023-04-19                SSW                    9.0                  1022.1
# 2023-04-20                 SW                    4.0                  1025.5
# 2023-04-21                SSE                    2.0                  1029.2
# 2023-04-22                SSW                   11.0                  1029.7
# 2023-04-23                SSW                   13.0                  1032.4
#
# [174 rows x 16 columns]

# %%
print(df_weather.isna().sum())
# 9 values in 9am wind speed column has NaN values. decided to impute mean values
df_weather['9am wind speed (km/h)'].fillna(df_weather['9am wind speed (km/h)'].mean(), inplace=True)
df_weather.describe()
# Out:
# Minimum temperature (°C)             0
# Maximum temperature (°C)             0
# Rainfall (mm)                        0
# Direction of maximum wind gust       0
# Speed of maximum wind gust (km/h)    0
# Time of maximum wind gust            0
# 9am Temperature (°C)                 0
# 9am relative humidity (%)            0
# 9am wind direction                   0
# 9am wind speed (km/h)                0
# 9am MSL pressure (hPa)               0
# 3pm Temperature (°C)                 0
# 3pm relative humidity (%)            0
# 3pm wind direction                   0
# 3pm wind speed (km/h)                0
# 3pm MSL pressure (hPa)               0
# dtype: int64
#        Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# count                174.000000                174.000000     174.000000
# mean                  14.072414                 23.121839       1.786207
# std                    3.228188                  5.419904       4.318081
# min                    6.900000                 13.100000       0.000000
# 25%                   11.700000                 19.300000       0.000000
# 50%                   14.150000                 21.700000       0.000000
# 75%                   16.075000                 26.275000       1.400000
# max                   25.000000                 40.500000      38.400000
#
#        Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# count                         174.000000             174.00000
# mean                           34.563218              17.30000
# std                             9.083048               3.55235
# min                            13.000000              10.10000
# 25%                            28.000000              14.90000
# 50%                            33.000000              16.90000
# 75%                            41.000000              18.70000
# max                            59.000000              29.90000
#
#        9am relative humidity (%)  9am wind speed (km/h)  \
# count                  174.00000             174.000000
# mean                    68.66092               9.806061
# std                     12.42294               4.088468
# min                     32.00000               2.000000
# 25%                     63.00000               7.000000
# 50%                     68.00000               9.000000
# 75%                     76.00000              13.000000
# max                    100.00000              24.000000
#
#        9am MSL pressure (hPa)  3pm Temperature (°C)  \
# count              174.000000            174.000000
# mean              1014.363218             21.546552
# std                  7.008131              5.255205
# min                991.300000             10.800000
# 25%               1011.100000             18.125000
# 50%               1014.850000             20.400000
# 75%               1018.675000             24.275000
# max               1034.400000             39.600000
#
#        3pm relative humidity (%)  3pm wind speed (km/h)  \
# count                 174.000000             174.000000
# mean                   54.298851              13.045977
# std                    15.155163               4.246476
# min                    16.000000               2.000000
# 25%                    44.000000              11.000000
# 50%                    55.500000              13.000000
# 75%                    64.750000              15.000000
# max                    97.000000              28.000000
#
#        3pm MSL pressure (hPa)
# count              174.000000
# mean              1012.819540
# std                  6.864583
# min                990.300000
# 25%               1008.900000
# 50%               1012.950000
# 75%               1016.900000
# max               1032.400000

# %% [markdown]
# # PRICE DEMAND DATA

# %%
df_price_demand = pd.read_csv("price_and_demand.csv")
display(df_price_demand)
df_price_demand.isnull().sum()
# we have 8351 rows and 5 columns with no missing data
# missing column headers .
# Out:
#       VIC1    1/11/2022 0:30  4178.18   8.94  TRADE
# 0     VIC1    1/11/2022 1:00  4086.02   0.14  TRADE
# 1     VIC1    1/11/2022 1:30  4033.37   0.02  TRADE
# 2     VIC1    1/11/2022 2:00  3985.64   0.00  TRADE
# 3     VIC1    1/11/2022 2:30  3885.64   0.02  TRADE
# 4     VIC1    1/11/2022 3:00  3919.59   1.04  TRADE
# ...    ...               ...      ...    ...    ...
# 8346  VIC1  23/04/2023 22:00  4717.55  84.09  TRADE
# 8347  VIC1  23/04/2023 22:30  4520.39  81.25  TRADE
# 8348  VIC1  23/04/2023 23:00  4472.49  93.97  TRADE
# 8349  VIC1  23/04/2023 23:30  4621.36  83.96  TRADE
# 8350  VIC1   24/04/2023 0:00  4395.96  63.77  TRADE
#
# [8351 rows x 5 columns]
# VIC1              0
# 1/11/2022 0:30    0
# 4178.18           0
# 8.94              0
# TRADE             0
# dtype: int64

# %%
# according to AEMO historical data . The headers are REGION SETTLEMENTDATE	TOTALDEMAND	RRP	PERIODTYPE
# we can add those headers to our dataframe.
col_index = ["Region", "Date_Time", "Total_Demand", "Price", "Period_type"]
df_price_demand.columns = col_index
df_price_demand.set_index("Date_Time", inplace=True)

# %%
df_price_demand.head(50)
# Out:
#                 Region  Total_Demand  Price Period_type
# Date_Time
# 1/11/2022 1:00    VIC1       4086.02   0.14       TRADE
# 1/11/2022 1:30    VIC1       4033.37   0.02       TRADE
# 1/11/2022 2:00    VIC1       3985.64   0.00       TRADE
# 1/11/2022 2:30    VIC1       3885.64   0.02       TRADE
# 1/11/2022 3:00    VIC1       3919.59   1.04       TRADE
# 1/11/2022 3:30    VIC1       3806.64   0.12       TRADE
# 1/11/2022 4:00    VIC1       3794.22  15.95       TRADE
# 1/11/2022 4:30    VIC1       3772.77   0.02       TRADE
# 1/11/2022 5:00    VIC1       3923.90   0.00       TRADE
# 1/11/2022 5:30    VIC1       4203.54   9.95       TRADE
# 1/11/2022 6:00    VIC1       4411.04   0.02       TRADE
# 1/11/2022 6:30    VIC1       4441.65   8.94       TRADE
# 1/11/2022 7:00    VIC1       4423.77   1.73       TRADE
# 1/11/2022 7:30    VIC1       4251.17   8.94       TRADE
# 1/11/2022 8:00    VIC1       4079.02   0.00       TRADE
# 1/11/2022 8:30    VIC1       4020.14  84.06       TRADE
# 1/11/2022 9:00    VIC1       4071.85 -38.00       TRADE
# 1/11/2022 9:30    VIC1       4056.44 -38.50       TRADE
# 1/11/2022 10:00   VIC1       3973.33  -0.90       TRADE
# 1/11/2022 10:30   VIC1       3870.49  -7.84       TRADE
# 1/11/2022 11:00   VIC1       4281.61 -37.43       TRADE
# 1/11/2022 11:30   VIC1       4319.85  62.00       TRADE
# 1/11/2022 12:00   VIC1       4435.22   3.74       TRADE
# 1/11/2022 12:30   VIC1       4370.62 -38.00       TRADE
# 1/11/2022 13:00   VIC1       4149.44 -28.86       TRADE
# 1/11/2022 13:30   VIC1       3933.02 -38.00       TRADE
# 1/11/2022 14:00   VIC1       3890.34 -38.67       TRADE
# 1/11/2022 14:30   VIC1       4108.05 -38.00       TRADE
# 1/11/2022 15:00   VIC1       4397.36 -38.50       TRADE
# 1/11/2022 15:30   VIC1       4472.59 -38.00       TRADE
# 1/11/2022 16:00   VIC1       4411.05 -38.00       TRADE
# 1/11/2022 16:30   VIC1       4749.83 -38.00       TRADE
# 1/11/2022 17:00   VIC1       5014.71  23.87       TRADE
# 1/11/2022 17:30   VIC1       5218.17   8.94       TRADE
# 1/11/2022 18:00   VIC1       5329.77  15.20       TRADE
# 1/11/2022 18:30   VIC1       5492.63  -9.44       TRADE
# 1/11/2022 19:00   VIC1       5542.56   0.00       TRADE
# 1/11/2022 19:30   VIC1       5627.52   0.00       TRADE
# 1/11/2022 20:00   VIC1       5473.00   8.94       TRADE
# 1/11/2022 20:30   VIC1       5376.31  27.57       TRADE
# 1/11/2022 21:00   VIC1       5108.43   8.94       TRADE
# 1/11/2022 21:30   VIC1       4864.74   8.94       TRADE
# 1/11/2022 22:00   VIC1       4473.18   0.00       TRADE
# 1/11/2022 22:30   VIC1       4389.24  -6.78       TRADE
# 1/11/2022 23:00   VIC1       4313.90  -4.78       TRADE
# 1/11/2022 23:30   VIC1       4497.91  -7.17       TRADE
# 2/11/2022 0:00    VIC1       4472.30  -6.75       TRADE
# 2/11/2022 0:30    VIC1       4337.38  -5.93       TRADE
# 2/11/2022 1:00    VIC1       4295.03  -4.32       TRADE
# 2/11/2022 1:30    VIC1       4246.18  -2.01       TRADE

# %%
# the period_type is trade for all values and region is VIC1 for all values as well. droping the constants
df_price_demand.drop(columns=["Region", "Period_type"], inplace=True)

# %%
# df_price_demand['Date_Time'] = pd.to_datetime(df_price_demand['Date_Time'], format='%d/%m/%Y %H:%M')

# # Set the "Date_Time" column as the DataFrame index
# df_price_demand.set_index('Date_Time', inplace=True)

# # Resample the data to daily intervals and aggregate the demand by summing the values for each day
# daily_demand = df_price_demand['Total_Demand'].resample('D').sum()

# print(daily_demand)
df_price_demand.index = pd.to_datetime(df_price_demand.index, format="mixed", dayfirst=True)
df_price_demand.isna().sum()
# Out:
# Total_Demand    0
# Price           0
# dtype: int64

# %%
df_price_demand.index.dtype
# Out:
# dtype('<M8[ns]')
