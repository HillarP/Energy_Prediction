# %% [markdown]
# Assignment 2 - Group 1

# %% [markdown]
# Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a DataFrame from a csv file
weather = pd.read_csv("weather.csv", encoding = "latin-1") # Had to use latin-1 for it to run due to encoding error

# %%
# INITIAL EXPLORATION OF DATA / SUMMARY STATISTICS

# %%
# Take a look at the first 10 rows
weather.head()
# Out:
#                              Location       Date  Minimum temperature (°C)  \
# 0  Melbourne (Olympic Park), Victoria  1/11/2022                       8.5
# 1  Melbourne (Olympic Park), Victoria  2/11/2022                       6.9
# 2  Melbourne (Olympic Park), Victoria  3/11/2022                       9.1
# 3  Melbourne (Olympic Park), Victoria  4/11/2022                      10.2
# 4  Melbourne (Olympic Park), Victoria  5/11/2022                      11.8
#
#    Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 0                      13.3            3.0               NaN
# 1                      15.7            2.8               NaN
# 2                      15.4            0.4               NaN
# 3                      17.8            0.2               NaN
# 4                      22.7            0.0               NaN
#
#    Sunshine (hours) Direction of maximum wind gust   \
# 0               NaN                              SW
# 1               NaN                             SSW
# 2               NaN                             SSW
# 3               NaN                               S
# 4               NaN                               N
#
#    Speed of maximum wind gust (km/h) Time of maximum wind gust  ...  \
# 0                               44.0                     11:36  ...
# 1                               43.0                     11:33  ...
# 2                               31.0                      8:07  ...
# 3                               24.0                     14:50  ...
# 4                               31.0                     11:58  ...
#
#    9am cloud amount (oktas)  9am wind direction  9am wind speed (km/h)  \
# 0                       NaN                  NW                     13
# 1                       NaN                   W                      9
# 2                       NaN                 SSW                      9
# 3                       NaN                 WSW                      6
# 4                       NaN                   N                      9
#
#   9am MSL pressure (hPa) 3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                  991.3                 13.2                       59.0
# 1                 1006.7                 15.1                       54.0
# 2                 1019.2                 13.8                       67.0
# 3                 1028.1                 16.9                       56.0
# 4                 1026.3                 18.8                       65.0
#
#    3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                       NaN                 WNW                   11.0
# 1                       NaN                 SSW                   13.0
# 2                       NaN                 SSW                    9.0
# 3                       NaN                  SW                    9.0
# 4                       NaN                  SW                   11.0
#
#   3pm MSL pressure (hPa)
# 0                  991.5
# 1                 1008.4
# 2                 1021.3
# 3                 1026.6
# 4                 1023.2
#
# [5 rows x 22 columns]

# %%
# Check shape
weather.shape
# Out:
# (175, 22)

# %%
# Check for duplicate rows
weather.duplicated().sum()
# Out:
# 0

# %%
# Check dtypes
weather.dtypes
# Out:
# Location                              object
# Date                                  object
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Evaporation (mm)                     float64
# Sunshine (hours)                     float64
# Direction of maximum wind gust        object
# Speed of maximum wind gust (km/h)    float64
# Time of maximum wind gust             object
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)              int64
# 9am cloud amount (oktas)             float64
# 9am wind direction                    object
# 9am wind speed (km/h)                 object
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)            float64
# 3pm cloud amount (oktas)             float64
# 3pm wind direction                    object
# 3pm wind speed (km/h)                float64
# 3pm MSL pressure (hPa)               float64
# dtype: object

# %%
# Do these match what we expected?

# Note that "9am wind speed (km/h)" is listing "object" instead of the expected int64

# %%
# Check missing values per column
weather.isna().sum()
# Out:
# Location                               0
# Date                                   0
# Minimum temperature (°C)               0
# Maximum temperature (°C)               1
# Rainfall (mm)                          0
# Evaporation (mm)                     175
# Sunshine (hours)                     175
# Direction of maximum wind gust         1
# Speed of maximum wind gust (km/h)      1
# Time of maximum wind gust              1
# 9am Temperature (°C)                   0
# 9am relative humidity (%)              0
# 9am cloud amount (oktas)             175
# 9am wind direction                     0
# 9am wind speed (km/h)                  0
# 9am MSL pressure (hPa)                 0
# 3pm Temperature (°C)                   1
# 3pm relative humidity (%)              1
# 3pm cloud amount (oktas)             175
# 3pm wind direction                     1
# 3pm wind speed (km/h)                  1
# 3pm MSL pressure (hPa)                 1
# dtype: int64

# %%
# In the csv file there are multiple missing values for the "9am wind direction" column, yet here it's displaying 0? 
# Empty string might not be included in na values and might therefore not show up

# %%
# Check missing values per rows
weather.isna().sum(axis=1)
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 170     4
# 171     4
# 172     4
# 173     4
# 174    13
# Length: 175, dtype: int64

# %%
# Note column 174 has 13 missing values

# %%
# Get basic summary statistics for weather
weather.describe()
# Out:
#        Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# count                175.000000                174.000000     175.000000
# mean                  14.054857                 23.121839       1.776000
# std                    3.227267                  5.419904       4.307771
# min                    6.900000                 13.100000       0.000000
# 25%                   11.700000                 19.300000       0.000000
# 50%                   14.100000                 21.700000       0.000000
# 75%                   16.050000                 26.275000       1.400000
# max                   25.000000                 40.500000      38.400000
#
#        Evaporation (mm)  Sunshine (hours)  Speed of maximum wind gust (km/h)  \
# count               0.0               0.0                         174.000000
# mean                NaN               NaN                          34.563218
# std                 NaN               NaN                           9.083048
# min                 NaN               NaN                          13.000000
# 25%                 NaN               NaN                          28.000000
# 50%                 NaN               NaN                          33.000000
# 75%                 NaN               NaN                          41.000000
# max                 NaN               NaN                          59.000000
#
#        9am Temperature (°C)  9am relative humidity (%)  \
# count            175.000000                 175.000000
# mean              17.282857                  68.765714
# std                3.549380                  12.464523
# min               10.100000                  32.000000
# 25%               14.850000                  63.000000
# 50%               16.800000                  68.000000
# 75%               18.700000                  76.000000
# max               29.900000                 100.000000
#
#        9am cloud amount (oktas)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# count                       0.0              175.000000            174.000000
# mean                        NaN             1014.466857             21.546552
# std                         NaN                7.121187              5.255205
# min                         NaN              991.300000             10.800000
# 25%                         NaN             1011.200000             18.125000
# 50%                         NaN             1014.900000             20.400000
# 75%                         NaN             1018.800000             24.275000
# max                         NaN             1034.400000             39.600000
#
#        3pm relative humidity (%)  3pm cloud amount (oktas)  \
# count                 174.000000                       0.0
# mean                   54.298851                       NaN
# std                    15.155163                       NaN
# min                    16.000000                       NaN
# 25%                    44.000000                       NaN
# 50%                    55.500000                       NaN
# 75%                    64.750000                       NaN
# max                    97.000000                       NaN
#
#        3pm wind speed (km/h)  3pm MSL pressure (hPa)
# count             174.000000              174.000000
# mean               13.045977             1012.819540
# std                 4.246476                6.864583
# min                 2.000000              990.300000
# 25%                11.000000             1008.900000
# 50%                13.000000             1012.950000
# 75%                15.000000             1016.900000
# max                28.000000             1032.400000

# %%
# Looks plausible from the outset - we have domain knowledge as Melbourne citizens for general temperatures

# %%
weather.tail()
# Out:
#                                Location        Date  Minimum temperature (°C)  \
# 170  Melbourne (Olympic Park), Victoria  20/04/2023                       7.8
# 171  Melbourne (Olympic Park), Victoria  21/04/2023                      11.3
# 172  Melbourne (Olympic Park), Victoria  22/04/2023                      14.6
# 173  Melbourne (Olympic Park), Victoria  23/04/2023                      14.8
# 174  Melbourne (Olympic Park), Victoria  24/04/2023                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 170                      18.5            0.0               NaN
# 171                      19.0            0.0               NaN
# 172                      19.2            0.0               NaN
# 173                      19.0            0.0               NaN
# 174                       NaN            0.0               NaN
#
#      Sunshine (hours) Direction of maximum wind gust   \
# 170               NaN                             SSW
# 171               NaN                             SSW
# 172               NaN                             SSW
# 173               NaN                             SSW
# 174               NaN                             NaN
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  ...  \
# 170                               17.0                     12:47  ...
# 171                               13.0                     10:48  ...
# 172                               22.0                     16:09  ...
# 173                               26.0                     15:45  ...
# 174                                NaN                       NaN  ...
#
#      9am cloud amount (oktas)  9am wind direction  9am wind speed (km/h)  \
# 170                       NaN                 NNE                      7
# 171                       NaN                  NE                      6
# 172                       NaN                  SW                      6
# 173                       NaN                 SSE                      7
# 174                       NaN                  NE                      9
#
#     9am MSL pressure (hPa) 3pm Temperature (°C)  3pm relative humidity (%)  \
# 170                 1026.8                 17.5                       58.0
# 171                 1030.5                 18.6                       64.0
# 172                 1031.9                 18.8                       64.0
# 173                 1034.4                 17.8                       71.0
# 174                 1032.5                  NaN                        NaN
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 170                       NaN                  SW                    4.0
# 171                       NaN                 SSE                    2.0
# 172                       NaN                 SSW                   11.0
# 173                       NaN                 SSW                   13.0
# 174                       NaN                 NaN                    NaN
#
#     3pm MSL pressure (hPa)
# 170                 1025.5
# 171                 1029.2
# 172                 1029.7
# 173                 1032.4
# 174                    NaN
#
# [5 rows x 22 columns]

# %%
# Get column labels
weather.columns.values
# Out:
# array(['Location', 'Date', 'Minimum temperature (°C)',
#        'Maximum temperature (°C)', 'Rainfall (mm)', 'Evaporation (mm)',
#        'Sunshine (hours)', 'Direction of maximum wind gust ',
#        'Speed of maximum wind gust (km/h)', 'Time of maximum wind gust',
#        '9am Temperature (°C)', '9am relative humidity (%)',
#        '9am cloud amount (oktas)', '9am wind direction',
#        '9am wind speed (km/h)', '9am MSL pressure (hPa)',
#        '3pm Temperature (°C)', '3pm relative humidity (%)',
#        '3pm cloud amount (oktas)', '3pm wind direction',
#        '3pm wind speed (km/h)', '3pm MSL pressure (hPa)'], dtype=object)

# %%
to_drop = ["Location", "Evaporation (mm)", "Sunshine (hours)", "Direction of maximum wind gust ", 
           'Time of maximum wind gust', "9am cloud amount (oktas)", '9am wind direction',
           "3pm cloud amount (oktas)", "3pm wind direction"]
weather.drop(to_drop, inplace=True, axis=1)

# %%
weather.head()
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/11/2022                       8.5                      13.3
# 1  2/11/2022                       6.9                      15.7
# 2  3/11/2022                       9.1                      15.4
# 3  4/11/2022                      10.2                      17.8
# 4  5/11/2022                      11.8                      22.7
#
#    Rainfall (mm)  Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# 0            3.0                               44.0                  12.0
# 1            2.8                               43.0                  11.0
# 2            0.4                               31.0                  11.5
# 3            0.2                               24.0                  12.3
# 4            0.0                               31.0                  14.0
#
#    9am relative humidity (%) 9am wind speed (km/h)  9am MSL pressure (hPa)  \
# 0                         64                    13                   991.3
# 1                         65                     9                  1006.7
# 2                         70                     9                  1019.2
# 3                         84                     6                  1028.1
# 4                         78                     9                  1026.3
#
#    3pm Temperature (°C)  3pm relative humidity (%)  3pm wind speed (km/h)  \
# 0                  13.2                       59.0                   11.0
# 1                  15.1                       54.0                   13.0
# 2                  13.8                       67.0                    9.0
# 3                  16.9                       56.0                    9.0
# 4                  18.8                       65.0                   11.0
#
#    3pm MSL pressure (hPa)
# 0                   991.5
# 1                  1008.4
# 2                  1021.3
# 3                  1026.6
# 4                  1023.2

# %%
# Set Date as Index Column
weather.set_index("Date", inplace=True)
weather.head()
# Out:
#            Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 1/11/2022                       8.5                      13.3            3.0
# 2/11/2022                       6.9                      15.7            2.8
# 3/11/2022                       9.1                      15.4            0.4
# 4/11/2022                      10.2                      17.8            0.2
# 5/11/2022                      11.8                      22.7            0.0
#
#            Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# Date
# 1/11/2022                               44.0                  12.0
# 2/11/2022                               43.0                  11.0
# 3/11/2022                               31.0                  11.5
# 4/11/2022                               24.0                  12.3
# 5/11/2022                               31.0                  14.0
#
#            9am relative humidity (%) 9am wind speed (km/h)  \
# Date
# 1/11/2022                         64                    13
# 2/11/2022                         65                     9
# 3/11/2022                         70                     9
# 4/11/2022                         84                     6
# 5/11/2022                         78                     9
#
#            9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 1/11/2022                   991.3                  13.2
# 2/11/2022                  1006.7                  15.1
# 3/11/2022                  1019.2                  13.8
# 4/11/2022                  1028.1                  16.9
# 5/11/2022                  1026.3                  18.8
#
#            3pm relative humidity (%)  3pm wind speed (km/h)  \
# Date
# 1/11/2022                       59.0                   11.0
# 2/11/2022                       54.0                   13.0
# 3/11/2022                       67.0                    9.0
# 4/11/2022                       56.0                    9.0
# 5/11/2022                       65.0                   11.0
#
#            3pm MSL pressure (hPa)
# Date
# 1/11/2022                   991.5
# 2/11/2022                  1008.4
# 3/11/2022                  1021.3
# 4/11/2022                  1026.6
# 5/11/2022                  1023.2

# %%
weather.tail()
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 20/04/2023                       7.8                      18.5            0.0
# 21/04/2023                      11.3                      19.0            0.0
# 22/04/2023                      14.6                      19.2            0.0
# 23/04/2023                      14.8                      19.0            0.0
# 24/04/2023                      11.0                       NaN            0.0
#
#             Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# Date
# 20/04/2023                               17.0                  12.4
# 21/04/2023                               13.0                  14.8
# 22/04/2023                               22.0                  15.2
# 23/04/2023                               26.0                  16.7
# 24/04/2023                                NaN                  14.3
#
#             9am relative humidity (%) 9am wind speed (km/h)  \
# Date
# 20/04/2023                         72                     7
# 21/04/2023                         78                     6
# 22/04/2023                         84                     6
# 23/04/2023                         79                     7
# 24/04/2023                         87                     9
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 20/04/2023                  1026.8                  17.5
# 21/04/2023                  1030.5                  18.6
# 22/04/2023                  1031.9                  18.8
# 23/04/2023                  1034.4                  17.8
# 24/04/2023                  1032.5                   NaN
#
#             3pm relative humidity (%)  3pm wind speed (km/h)  \
# Date
# 20/04/2023                       58.0                    4.0
# 21/04/2023                       64.0                    2.0
# 22/04/2023                       64.0                   11.0
# 23/04/2023                       71.0                   13.0
# 24/04/2023                        NaN                    NaN
#
#             3pm MSL pressure (hPa)
# Date
# 20/04/2023                  1025.5
# 21/04/2023                  1029.2
# 22/04/2023                  1029.7
# 23/04/2023                  1032.4
# 24/04/2023                     NaN

# %%
# Drop last row due to multiple missing datapoints
weather.drop("24/04/2023", inplace=True)
weather.tail()
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 19/04/2023                      14.4                      17.5            1.2
# 20/04/2023                       7.8                      18.5            0.0
# 21/04/2023                      11.3                      19.0            0.0
# 22/04/2023                      14.6                      19.2            0.0
# 23/04/2023                      14.8                      19.0            0.0
#
#             Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# Date
# 19/04/2023                               28.0                  14.8
# 20/04/2023                               17.0                  12.4
# 21/04/2023                               13.0                  14.8
# 22/04/2023                               22.0                  15.2
# 23/04/2023                               26.0                  16.7
#
#             9am relative humidity (%) 9am wind speed (km/h)  \
# Date
# 19/04/2023                         66                     9
# 20/04/2023                         72                     7
# 21/04/2023                         78                     6
# 22/04/2023                         84                     6
# 23/04/2023                         79                     7
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 19/04/2023                  1022.0                  15.8
# 20/04/2023                  1026.8                  17.5
# 21/04/2023                  1030.5                  18.6
# 22/04/2023                  1031.9                  18.8
# 23/04/2023                  1034.4                  17.8
#
#             3pm relative humidity (%)  3pm wind speed (km/h)  \
# Date
# 19/04/2023                       53.0                    9.0
# 20/04/2023                       58.0                    4.0
# 21/04/2023                       64.0                    2.0
# 22/04/2023                       64.0                   11.0
# 23/04/2023                       71.0                   13.0
#
#             3pm MSL pressure (hPa)
# Date
# 19/04/2023                  1022.1
# 20/04/2023                  1025.5
# 21/04/2023                  1029.2
# 22/04/2023                  1029.7
# 23/04/2023                  1032.4

# %%
# Checking quality of remaining data

# Missing values from rows
weather.isna().sum()
# Out:
# Minimum temperature (°C)             0
# Maximum temperature (°C)             0
# Rainfall (mm)                        0
# Speed of maximum wind gust (km/h)    0
# 9am Temperature (°C)                 0
# 9am relative humidity (%)            0
# 9am wind speed (km/h)                0
# 9am MSL pressure (hPa)               0
# 3pm Temperature (°C)                 0
# 3pm relative humidity (%)            0
# 3pm wind speed (km/h)                0
# 3pm MSL pressure (hPa)               0
# dtype: int64

# %%
# Object types
weather.dtypes
# Out:
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Speed of maximum wind gust (km/h)    float64
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)              int64
# 9am wind speed (km/h)                 object
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)            float64
# 3pm wind speed (km/h)                float64
# 3pm MSL pressure (hPa)               float64
# dtype: object

# %%
#9am wind speed (km/h) shows a data type of "object"
#Upon inspection of the data, it seems that where there was no wind, instead of 0, the input was "Calm"
# Locate values for comparison

weather[["9am wind speed (km/h)"]].tail(40)
# Out:
#            9am wind speed (km/h)
# Date
# 15/03/2023                     6
# 16/03/2023                    11
# 17/03/2023                     7
# 18/03/2023                    13
# 19/03/2023                     7
# 20/03/2023                    17
# 21/03/2023                     6
# 22/03/2023                     2
# 23/03/2023                     9
# 24/03/2023                     7
# 25/03/2023                     9
# 26/03/2023                  Calm
# 27/03/2023                     9
# 28/03/2023                  Calm
# 29/03/2023                     7
# 30/03/2023                     9
# 31/03/2023                     6
# 1/04/2023                      9
# 2/04/2023                      6
# 3/04/2023                      7
# 4/04/2023                      7
# 5/04/2023                      2
# 6/04/2023                      6
# 7/04/2023                     13
# 8/04/2023                     13
# 9/04/2023                      9
# 10/04/2023                    15
# 11/04/2023                     2
# 12/04/2023                    13
# 13/04/2023                     4
# 14/04/2023                     9
# 15/04/2023                    20
# 16/04/2023                     9
# 17/04/2023                     7
# 18/04/2023                     7
# 19/04/2023                     9
# 20/04/2023                     7
# 21/04/2023                     6
# 22/04/2023                     6
# 23/04/2023                     7

# %%
#Replace "Calm" with 0 using domain knowledge


#Strip whitespace and convert all to int just to make sure
weather["9am wind speed (km/h)"] = weather["9am wind speed (km/h)"].str.strip()

weather["9am wind speed (km/h)"] = weather["9am wind speed (km/h)"].replace("Calm", 0)


weather[["9am wind speed (km/h)"]].tail(40)
# Out:
#            9am wind speed (km/h)
# Date
# 15/03/2023                     6
# 16/03/2023                    11
# 17/03/2023                     7
# 18/03/2023                    13
# 19/03/2023                     7
# 20/03/2023                    17
# 21/03/2023                     6
# 22/03/2023                     2
# 23/03/2023                     9
# 24/03/2023                     7
# 25/03/2023                     9
# 26/03/2023                     0
# 27/03/2023                     9
# 28/03/2023                     0
# 29/03/2023                     7
# 30/03/2023                     9
# 31/03/2023                     6
# 1/04/2023                      9
# 2/04/2023                      6
# 3/04/2023                      7
# 4/04/2023                      7
# 5/04/2023                      2
# 6/04/2023                      6
# 7/04/2023                     13
# 8/04/2023                     13
# 9/04/2023                      9
# 10/04/2023                    15
# 11/04/2023                     2
# 12/04/2023                    13
# 13/04/2023                     4
# 14/04/2023                     9
# 15/04/2023                    20
# 16/04/2023                     9
# 17/04/2023                     7
# 18/04/2023                     7
# 19/04/2023                     9
# 20/04/2023                     7
# 21/04/2023                     6
# 22/04/2023                     6
# 23/04/2023                     7

# %%
weather["9am wind speed (km/h)"] = pd.to_numeric(weather["9am wind speed (km/h)"], errors='coerce').astype(pd.Int64Dtype())



# Check that all data is numeric now (YAY!)
weather.dtypes
# Out:
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Speed of maximum wind gust (km/h)    float64
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)              int64
# 9am wind speed (km/h)                  Int64
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)            float64
# 3pm wind speed (km/h)                float64
# 3pm MSL pressure (hPa)               float64
# dtype: object

# %%
display(weather)
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 1/11/2022                        8.5                      13.3            3.0
# 2/11/2022                        6.9                      15.7            2.8
# 3/11/2022                        9.1                      15.4            0.4
# 4/11/2022                       10.2                      17.8            0.2
# 5/11/2022                       11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 19/04/2023                      14.4                      17.5            1.2
# 20/04/2023                       7.8                      18.5            0.0
# 21/04/2023                      11.3                      19.0            0.0
# 22/04/2023                      14.6                      19.2            0.0
# 23/04/2023                      14.8                      19.0            0.0
#
#             Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# Date
# 1/11/2022                                44.0                  12.0
# 2/11/2022                                43.0                  11.0
# 3/11/2022                                31.0                  11.5
# 4/11/2022                                24.0                  12.3
# 5/11/2022                                31.0                  14.0
# ...                                       ...                   ...
# 19/04/2023                               28.0                  14.8
# 20/04/2023                               17.0                  12.4
# 21/04/2023                               13.0                  14.8
# 22/04/2023                               22.0                  15.2
# 23/04/2023                               26.0                  16.7
#
#             9am relative humidity (%)  9am wind speed (km/h)  \
# Date
# 1/11/2022                          64                     13
# 2/11/2022                          65                      9
# 3/11/2022                          70                      9
# 4/11/2022                          84                      6
# 5/11/2022                          78                      9
# ...                               ...                    ...
# 19/04/2023                         66                      9
# 20/04/2023                         72                      7
# 21/04/2023                         78                      6
# 22/04/2023                         84                      6
# 23/04/2023                         79                      7
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 1/11/2022                    991.3                  13.2
# 2/11/2022                   1006.7                  15.1
# 3/11/2022                   1019.2                  13.8
# 4/11/2022                   1028.1                  16.9
# 5/11/2022                   1026.3                  18.8
# ...                            ...                   ...
# 19/04/2023                  1022.0                  15.8
# 20/04/2023                  1026.8                  17.5
# 21/04/2023                  1030.5                  18.6
# 22/04/2023                  1031.9                  18.8
# 23/04/2023                  1034.4                  17.8
#
#             3pm relative humidity (%)  3pm wind speed (km/h)  \
# Date
# 1/11/2022                        59.0                   11.0
# 2/11/2022                        54.0                   13.0
# 3/11/2022                        67.0                    9.0
# 4/11/2022                        56.0                    9.0
# 5/11/2022                        65.0                   11.0
# ...                               ...                    ...
# 19/04/2023                       53.0                    9.0
# 20/04/2023                       58.0                    4.0
# 21/04/2023                       64.0                    2.0
# 22/04/2023                       64.0                   11.0
# 23/04/2023                       71.0                   13.0
#
#             3pm MSL pressure (hPa)
# Date
# 1/11/2022                    991.5
# 2/11/2022                   1008.4
# 3/11/2022                   1021.3
# 4/11/2022                   1026.6
# 5/11/2022                   1023.2
# ...                            ...
# 19/04/2023                  1022.1
# 20/04/2023                  1025.5
# 21/04/2023                  1029.2
# 22/04/2023                  1029.7
# 23/04/2023                  1032.4
#
# [174 rows x 12 columns]

# %%
# Change date to datatime format
weather.index = pd.to_datetime(weather.index, format='%d/%m/%Y')

# %%
display(weather)
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                       8.5                      13.3            3.0
# 2022-11-02                       6.9                      15.7            2.8
# 2022-11-03                       9.1                      15.4            0.4
# 2022-11-04                      10.2                      17.8            0.2
# 2022-11-05                      11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 2023-04-19                      14.4                      17.5            1.2
# 2023-04-20                       7.8                      18.5            0.0
# 2023-04-21                      11.3                      19.0            0.0
# 2023-04-22                      14.6                      19.2            0.0
# 2023-04-23                      14.8                      19.0            0.0
#
#             Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# Date
# 2022-11-01                               44.0                  12.0
# 2022-11-02                               43.0                  11.0
# 2022-11-03                               31.0                  11.5
# 2022-11-04                               24.0                  12.3
# 2022-11-05                               31.0                  14.0
# ...                                       ...                   ...
# 2023-04-19                               28.0                  14.8
# 2023-04-20                               17.0                  12.4
# 2023-04-21                               13.0                  14.8
# 2023-04-22                               22.0                  15.2
# 2023-04-23                               26.0                  16.7
#
#             9am relative humidity (%)  9am wind speed (km/h)  \
# Date
# 2022-11-01                         64                     13
# 2022-11-02                         65                      9
# 2022-11-03                         70                      9
# 2022-11-04                         84                      6
# 2022-11-05                         78                      9
# ...                               ...                    ...
# 2023-04-19                         66                      9
# 2023-04-20                         72                      7
# 2023-04-21                         78                      6
# 2023-04-22                         84                      6
# 2023-04-23                         79                      7
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 2022-11-01                   991.3                  13.2
# 2022-11-02                  1006.7                  15.1
# 2022-11-03                  1019.2                  13.8
# 2022-11-04                  1028.1                  16.9
# 2022-11-05                  1026.3                  18.8
# ...                            ...                   ...
# 2023-04-19                  1022.0                  15.8
# 2023-04-20                  1026.8                  17.5
# 2023-04-21                  1030.5                  18.6
# 2023-04-22                  1031.9                  18.8
# 2023-04-23                  1034.4                  17.8
#
#             3pm relative humidity (%)  3pm wind speed (km/h)  \
# Date
# 2022-11-01                       59.0                   11.0
# 2022-11-02                       54.0                   13.0
# 2022-11-03                       67.0                    9.0
# 2022-11-04                       56.0                    9.0
# 2022-11-05                       65.0                   11.0
# ...                               ...                    ...
# 2023-04-19                       53.0                    9.0
# 2023-04-20                       58.0                    4.0
# 2023-04-21                       64.0                    2.0
# 2023-04-22                       64.0                   11.0
# 2023-04-23                       71.0                   13.0
#
#             3pm MSL pressure (hPa)
# Date
# 2022-11-01                   991.5
# 2022-11-02                  1008.4
# 2022-11-03                  1021.3
# 2022-11-04                  1026.6
# 2022-11-05                  1023.2
# ...                            ...
# 2023-04-19                  1022.1
# 2023-04-20                  1025.5
# 2023-04-21                  1029.2
# 2023-04-22                  1029.7
# 2023-04-23                  1032.4
#
# [174 rows x 12 columns]

# %%
# Change to correct format
weather.index = weather.index.strftime('%d/%m/%Y')

# %%
display(weather)
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 01/11/2022                       8.5                      13.3            3.0
# 02/11/2022                       6.9                      15.7            2.8
# 03/11/2022                       9.1                      15.4            0.4
# 04/11/2022                      10.2                      17.8            0.2
# 05/11/2022                      11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 19/04/2023                      14.4                      17.5            1.2
# 20/04/2023                       7.8                      18.5            0.0
# 21/04/2023                      11.3                      19.0            0.0
# 22/04/2023                      14.6                      19.2            0.0
# 23/04/2023                      14.8                      19.0            0.0
#
#             Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# Date
# 01/11/2022                               44.0                  12.0
# 02/11/2022                               43.0                  11.0
# 03/11/2022                               31.0                  11.5
# 04/11/2022                               24.0                  12.3
# 05/11/2022                               31.0                  14.0
# ...                                       ...                   ...
# 19/04/2023                               28.0                  14.8
# 20/04/2023                               17.0                  12.4
# 21/04/2023                               13.0                  14.8
# 22/04/2023                               22.0                  15.2
# 23/04/2023                               26.0                  16.7
#
#             9am relative humidity (%)  9am wind speed (km/h)  \
# Date
# 01/11/2022                         64                     13
# 02/11/2022                         65                      9
# 03/11/2022                         70                      9
# 04/11/2022                         84                      6
# 05/11/2022                         78                      9
# ...                               ...                    ...
# 19/04/2023                         66                      9
# 20/04/2023                         72                      7
# 21/04/2023                         78                      6
# 22/04/2023                         84                      6
# 23/04/2023                         79                      7
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 01/11/2022                   991.3                  13.2
# 02/11/2022                  1006.7                  15.1
# 03/11/2022                  1019.2                  13.8
# 04/11/2022                  1028.1                  16.9
# 05/11/2022                  1026.3                  18.8
# ...                            ...                   ...
# 19/04/2023                  1022.0                  15.8
# 20/04/2023                  1026.8                  17.5
# 21/04/2023                  1030.5                  18.6
# 22/04/2023                  1031.9                  18.8
# 23/04/2023                  1034.4                  17.8
#
#             3pm relative humidity (%)  3pm wind speed (km/h)  \
# Date
# 01/11/2022                       59.0                   11.0
# 02/11/2022                       54.0                   13.0
# 03/11/2022                       67.0                    9.0
# 04/11/2022                       56.0                    9.0
# 05/11/2022                       65.0                   11.0
# ...                               ...                    ...
# 19/04/2023                       53.0                    9.0
# 20/04/2023                       58.0                    4.0
# 21/04/2023                       64.0                    2.0
# 22/04/2023                       64.0                   11.0
# 23/04/2023                       71.0                   13.0
#
#             3pm MSL pressure (hPa)
# Date
# 01/11/2022                   991.5
# 02/11/2022                  1008.4
# 03/11/2022                  1021.3
# 04/11/2022                  1026.6
# 05/11/2022                  1023.2
# ...                            ...
# 19/04/2023                  1022.1
# 20/04/2023                  1025.5
# 21/04/2023                  1029.2
# 22/04/2023                  1029.7
# 23/04/2023                  1032.4
#
# [174 rows x 12 columns]

# %% [markdown]
# PRICE_AND_DEMAND

# %%
price_and_demand = pd.read_csv("price_and_demand.csv", header = None)

# %%
price_and_demand.head(10)

# Note it has no headers - need to manually insert
# Out:
#       0               1        2      3      4
# 0  VIC1  1/11/2022 0:30  4178.18   8.94  TRADE
# 1  VIC1  1/11/2022 1:00  4086.02   0.14  TRADE
# 2  VIC1  1/11/2022 1:30  4033.37   0.02  TRADE
# 3  VIC1  1/11/2022 2:00  3985.64   0.00  TRADE
# 4  VIC1  1/11/2022 2:30  3885.64   0.02  TRADE
# 5  VIC1  1/11/2022 3:00  3919.59   1.04  TRADE
# 6  VIC1  1/11/2022 3:30  3806.64   0.12  TRADE
# 7  VIC1  1/11/2022 4:00  3794.22  15.95  TRADE
# 8  VIC1  1/11/2022 4:30  3772.77   0.02  TRADE
# 9  VIC1  1/11/2022 5:00  3923.90   0.00  TRADE

# %%
# Create headers
headers = ["Location", "Date & Time", "Total Demand", "Price", "Type"]
price_and_demand.columns = headers

# %%
price_and_demand.head()
# Out:
#   Location     Date & Time  Total Demand  Price   Type
# 0     VIC1  1/11/2022 0:30       4178.18   8.94  TRADE
# 1     VIC1  1/11/2022 1:00       4086.02   0.14  TRADE
# 2     VIC1  1/11/2022 1:30       4033.37   0.02  TRADE
# 3     VIC1  1/11/2022 2:00       3985.64   0.00  TRADE
# 4     VIC1  1/11/2022 2:30       3885.64   0.02  TRADE

# %%
# Check shape of df
price_and_demand.shape
# Out:
# (8352, 5)

# %%
# Check for dupplicated rows
price_and_demand.duplicated().sum()
# Out:
# 0

# %%
# Check dtypes
price_and_demand.dtypes
# Out:
# Location         object
# Date & Time      object
# Total Demand    float64
# Price           float64
# Type             object
# dtype: object

# %%
# Seems consistent - the numerical columns all contain floats and no strings

# %%
# Check missing values per column
price_and_demand.isna().sum()
# Out:
# Location        0
# Date & Time     0
# Total Demand    0
# Price           0
# Type            0
# dtype: int64

# %%
# No missing values in columns

# %%
price_and_demand.describe()
# Out:
#        Total Demand        Price
# count   8352.000000  8352.000000
# mean    4420.837294    54.629302
# std      788.543139    88.050149
# min     1976.530000  -981.820000
# 25%     3914.142500     0.000000
# 50%     4342.330000    72.000000
# 75%     4885.027500   106.222500
# max     8850.610000  3944.960000

# %%
# Min and max vlues seem to be quite high     min-918 (row 6361)    max-3944? (row 5170) - like everybody
# came back from work and turned on their aircon - check out that day specifically

# %%
price_and_demand.head()
# Out:
#   Location     Date & Time  Total Demand  Price   Type
# 0     VIC1  1/11/2022 0:30       4178.18   8.94  TRADE
# 1     VIC1  1/11/2022 1:00       4086.02   0.14  TRADE
# 2     VIC1  1/11/2022 1:30       4033.37   0.02  TRADE
# 3     VIC1  1/11/2022 2:00       3985.64   0.00  TRADE
# 4     VIC1  1/11/2022 2:30       3885.64   0.02  TRADE

# %%
# Drop the columns that I don't want - keep price for now just incase other group members think it might be relevant
to_drop = ["Location", "Type"]
price_and_demand.drop(to_drop, inplace=True, axis=1)

# %%
price_and_demand.head()
# Out:
#       Date & Time  Total Demand  Price
# 0  1/11/2022 0:30       4178.18   8.94
# 1  1/11/2022 1:00       4086.02   0.14
# 2  1/11/2022 1:30       4033.37   0.02
# 3  1/11/2022 2:00       3985.64   0.00
# 4  1/11/2022 2:30       3885.64   0.02

# %%
#Separate date & time
price_and_demand[['Date','Time']] = price_and_demand['Date & Time'].str.split(" ", n=1, expand=True)

# %%
price_and_demand.head()
# Out:
#       Date & Time  Total Demand  Price       Date  Time
# 0  1/11/2022 0:30       4178.18   8.94  1/11/2022  0:30
# 1  1/11/2022 1:00       4086.02   0.14  1/11/2022  1:00
# 2  1/11/2022 1:30       4033.37   0.02  1/11/2022  1:30
# 3  1/11/2022 2:00       3985.64   0.00  1/11/2022  2:00
# 4  1/11/2022 2:30       3885.64   0.02  1/11/2022  2:30

# %%
# Drop original Data & Time column, and additional Time column
to_drop = ["Date & Time", "Time"]
price_and_demand.drop(to_drop, inplace=True, axis=1)
price_and_demand.head()
# Out:
#    Total Demand  Price       Date
# 0       4178.18   8.94  1/11/2022
# 1       4086.02   0.14  1/11/2022
# 2       4033.37   0.02  1/11/2022
# 3       3985.64   0.00  1/11/2022
# 4       3885.64   0.02  1/11/2022

# %%
price_and_demand.set_index("Date", inplace=True)
price_and_demand.tail()
# Out:
#             Total Demand  Price
# Date
# 23/04/2023       4717.55  84.09
# 23/04/2023       4520.39  81.25
# 23/04/2023       4472.49  93.97
# 23/04/2023       4621.36  83.96
# 24/04/2023       4395.96  63.77

# %%
price_and_demand.head()
# Out:
#            Total Demand  Price
# Date
# 1/11/2022       4178.18   8.94
# 1/11/2022       4086.02   0.14
# 1/11/2022       4033.37   0.02
# 1/11/2022       3985.64   0.00
# 1/11/2022       3885.64   0.02

# %%
# Remove 24-04-23 for joining with weather data
price_and_demand.drop("24/04/2023", inplace=True)

# %%
price_and_demand.tail()
# Out:
#             Total Demand  Price
# Date
# 23/04/2023       4792.34  87.43
# 23/04/2023       4717.55  84.09
# 23/04/2023       4520.39  81.25
# 23/04/2023       4472.49  93.97
# 23/04/2023       4621.36  83.96

# %%
# Counting index values to determine if consistent
index_counts = price_and_demand.index.value_counts()
print(index_counts)
# Out:
# Date
# 27/01/2023    48
# 28/02/2023    48
# 20/02/2023    48
# 21/02/2023    48
# 22/02/2023    48
#               ..
# 30/12/2022    48
# 31/12/2022    48
# 1/01/2023     48
# 2/01/2023     48
# 1/11/2022     47
# Name: count, Length: 174, dtype: int64

# %%
# Only 47 datapoints for 1/11/2022 - will manually find data and impute

# %% [markdown]
# VIC1	1/11/2022 0:00	4455.59	44.58	TRADE
# ![image.png](attachment:image.png)

# %%
price_and_demand.head()
# Out:
#            Total Demand  Price
# Date
# 1/11/2022       4178.18   8.94
# 1/11/2022       4086.02   0.14
# 1/11/2022       4033.37   0.02
# 1/11/2022       3985.64   0.00
# 1/11/2022       3885.64   0.02

# %%
# Create new DataFrame to concat newrowdf = pd.DataFrame("1/11/2022", 4455.59, 44.58, index=["1/11/2022"])\
newrow = {"Total Demand":4455.59, "Price":44.58}
print(newrow)
# Out:
# {'Total Demand': 4455.59, 'Price': 44.58}

# %%
newrowdf = pd.DataFrame(newrow, index=["1/11/2022"])

# %%
print(newrowdf)
# Out:
#            Total Demand  Price
# 1/11/2022       4455.59  44.58

# %%
newrowdf.head()
# Out:
#            Total Demand  Price
# 1/11/2022       4455.59  44.58

# %%
price_and_demand.head(2)
# Out:
#            Total Demand  Price
# Date
# 1/11/2022       4178.18   8.94
# 1/11/2022       4086.02   0.14

# %%
price_and_demand_new = pd.concat([newrowdf, price_and_demand])

# %%
price_and_demand_new.head()
# Out:
#            Total Demand  Price
# 1/11/2022       4455.59  44.58
# 1/11/2022       4178.18   8.94
# 1/11/2022       4086.02   0.14
# 1/11/2022       4033.37   0.02
# 1/11/2022       3985.64   0.00

# %%
# Double check consistent amounts
# Counting index values to determine if consistent
index_counts = price_and_demand_new.index.value_counts()
print(index_counts)
# Out:
# 1/11/2022     48
# 28/02/2023    48
# 20/02/2023    48
# 21/02/2023    48
# 22/02/2023    48
#               ..
# 30/12/2022    48
# 31/12/2022    48
# 1/01/2023     48
# 2/01/2023     48
# 23/04/2023    48
# Name: count, Length: 174, dtype: int64

# %%
price_and_demand_new.head()
# Out:
#            Total Demand  Price
# 1/11/2022       4455.59  44.58
# 1/11/2022       4178.18   8.94
# 1/11/2022       4086.02   0.14
# 1/11/2022       4033.37   0.02
# 1/11/2022       3985.64   0.00

# %%
# Convert to datetime format to preserve ordering
price_and_demand_new.index = pd.to_datetime(price_and_demand_new.index, dayfirst=True)

# %%
price_and_demand_new.head()
# Out:
#             Total Demand  Price
# 2022-11-01       4455.59  44.58
# 2022-11-01       4178.18   8.94
# 2022-11-01       4086.02   0.14
# 2022-11-01       4033.37   0.02
# 2022-11-01       3985.64   0.00

# %%
# Change the Date to the correct format
price_and_demand_new.index = price_and_demand_new.index.strftime('%d/%m/%Y')

# %%
price_and_demand_new.head()
# Out:
#             Total Demand  Price
# 01/11/2022       4455.59  44.58
# 01/11/2022       4178.18   8.94
# 01/11/2022       4086.02   0.14
# 01/11/2022       4033.37   0.02
# 01/11/2022       3985.64   0.00

# %%
# Create new column with Max Demand for same index

#What are the max values for the for the first 2 unique indexes?
max_demand_for_1nov = price_and_demand_new.loc['01/11/2022', 'Total Demand'].max()

print(max_demand_for_1nov)


max_demand_for_2nov = price_and_demand_new.loc['02/11/2022', 'Total Demand'].max()
print(max_demand_for_2nov)

# price_and_demand_new["Max Demand"] =
# Out:
# 5627.52
# 6018.43

# %%
# Add Max Demand column that selects the maximum value from a particular date i.e. max for 01/11/2022
price_and_demand_new['Max Demand'] = price_and_demand_new.groupby(price_and_demand_new.index)['Total Demand'].transform('max')

# %%
price_and_demand_new.head()
# Out:
#             Total Demand  Price  Max Demand
# 01/11/2022       4455.59  44.58     5627.52
# 01/11/2022       4178.18   8.94     5627.52
# 01/11/2022       4086.02   0.14     5627.52
# 01/11/2022       4033.37   0.02     5627.52
# 01/11/2022       3985.64   0.00     5627.52

# %%
price_and_demand_new.tail()
# Out:
#             Total Demand  Price  Max Demand
# 23/04/2023       4792.34  87.43     5361.47
# 23/04/2023       4717.55  84.09     5361.47
# 23/04/2023       4520.39  81.25     5361.47
# 23/04/2023       4472.49  93.97     5361.47
# 23/04/2023       4621.36  83.96     5361.47

# %%
# Add Max Price column that selects the maximum value from a particular date i.e. max price for 01/11/2022
price_and_demand_new['Max Price'] = price_and_demand_new.groupby(price_and_demand_new.index)['Price'].transform('max')

# %%
price_and_demand_new.head()
# Out:
#             Total Demand  Price  Max Demand  Max Price
# 01/11/2022       4455.59  44.58     5627.52      84.06
# 01/11/2022       4178.18   8.94     5627.52      84.06
# 01/11/2022       4086.02   0.14     5627.52      84.06
# 01/11/2022       4033.37   0.02     5627.52      84.06
# 01/11/2022       3985.64   0.00     5627.52      84.06

# %%
# Delete duplicate columns

# %%
price_and_demand_new.head()
# Out:
#             Total Demand  Price  Max Demand  Max Price
# 01/11/2022       4455.59  44.58     5627.52      84.06
# 01/11/2022       4178.18   8.94     5627.52      84.06
# 01/11/2022       4086.02   0.14     5627.52      84.06
# 01/11/2022       4033.37   0.02     5627.52      84.06
# 01/11/2022       3985.64   0.00     5627.52      84.06

# %%
price_and_demand_new.index = price_and_demand_new.index.rename("Date")

# %%
price_and_demand_new.head()
# Out:
#             Total Demand  Price  Max Demand  Max Price
# Date
# 01/11/2022       4455.59  44.58     5627.52      84.06
# 01/11/2022       4178.18   8.94     5627.52      84.06
# 01/11/2022       4086.02   0.14     5627.52      84.06
# 01/11/2022       4033.37   0.02     5627.52      84.06
# 01/11/2022       3985.64   0.00     5627.52      84.06

# %%
price_and_demand_new.reset_index(inplace=True)  # Convert the index to a regular column
price_and_demand_new.drop_duplicates(subset='Date', keep='first', inplace=True)  # Drop duplicates based on the 'index' column
price_and_demand_new.set_index('Date', inplace=True)  # Set the 'index' column

# %%
price_and_demand_new.head()
# Out:
#             Total Demand   Price  Max Demand  Max Price
# Date
# 01/11/2022       4455.59   44.58     5627.52      84.06
# 02/11/2022       4472.30   -6.75     6018.43     112.30
# 03/11/2022       4661.52   59.99     6004.84     299.50
# 04/11/2022       4746.98  127.01     5757.62     276.70
# 05/11/2022       4593.25   93.98     4783.60     268.47

# %%
# # DOUBLE CHECKING DATAFRAMES CAN BE JOINED
price_and_demand_new.shape
price_and_demand_new.dtypes
price_and_demand_new.head()
# Out:
#             Total Demand   Price  Max Demand  Max Price
# Date
# 01/11/2022       4455.59   44.58     5627.52      84.06
# 02/11/2022       4472.30   -6.75     6018.43     112.30
# 03/11/2022       4661.52   59.99     6004.84     299.50
# 04/11/2022       4746.98  127.01     5757.62     276.70
# 05/11/2022       4593.25   93.98     4783.60     268.47

# %%
price_and_demand_new.tail()
# Out:
#             Total Demand   Price  Max Demand  Max Price
# Date
# 19/04/2023       4432.95  101.00     6042.88     299.50
# 20/04/2023       4697.97  141.00     6084.21     349.33
# 21/04/2023       4667.72  103.26     5903.60     309.23
# 22/04/2023       4662.14  135.86     5313.61     141.00
# 23/04/2023       4498.73   75.00     5361.47     285.16

# %%
df = pd.merge(weather, price_and_demand_new, left_index=True, right_index=True)

# %%
display(df)
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 01/11/2022                       8.5                      13.3            3.0
# 02/11/2022                       6.9                      15.7            2.8
# 03/11/2022                       9.1                      15.4            0.4
# 04/11/2022                      10.2                      17.8            0.2
# 05/11/2022                      11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 19/04/2023                      14.4                      17.5            1.2
# 20/04/2023                       7.8                      18.5            0.0
# 21/04/2023                      11.3                      19.0            0.0
# 22/04/2023                      14.6                      19.2            0.0
# 23/04/2023                      14.8                      19.0            0.0
#
#             Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# Date
# 01/11/2022                               44.0                  12.0
# 02/11/2022                               43.0                  11.0
# 03/11/2022                               31.0                  11.5
# 04/11/2022                               24.0                  12.3
# 05/11/2022                               31.0                  14.0
# ...                                       ...                   ...
# 19/04/2023                               28.0                  14.8
# 20/04/2023                               17.0                  12.4
# 21/04/2023                               13.0                  14.8
# 22/04/2023                               22.0                  15.2
# 23/04/2023                               26.0                  16.7
#
#             9am relative humidity (%)  9am wind speed (km/h)  \
# Date
# 01/11/2022                         64                     13
# 02/11/2022                         65                      9
# 03/11/2022                         70                      9
# 04/11/2022                         84                      6
# 05/11/2022                         78                      9
# ...                               ...                    ...
# 19/04/2023                         66                      9
# 20/04/2023                         72                      7
# 21/04/2023                         78                      6
# 22/04/2023                         84                      6
# 23/04/2023                         79                      7
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 01/11/2022                   991.3                  13.2
# 02/11/2022                  1006.7                  15.1
# 03/11/2022                  1019.2                  13.8
# 04/11/2022                  1028.1                  16.9
# 05/11/2022                  1026.3                  18.8
# ...                            ...                   ...
# 19/04/2023                  1022.0                  15.8
# 20/04/2023                  1026.8                  17.5
# 21/04/2023                  1030.5                  18.6
# 22/04/2023                  1031.9                  18.8
# 23/04/2023                  1034.4                  17.8
#
#             3pm relative humidity (%)  3pm wind speed (km/h)  \
# Date
# 01/11/2022                       59.0                   11.0
# 02/11/2022                       54.0                   13.0
# 03/11/2022                       67.0                    9.0
# 04/11/2022                       56.0                    9.0
# 05/11/2022                       65.0                   11.0
# ...                               ...                    ...
# 19/04/2023                       53.0                    9.0
# 20/04/2023                       58.0                    4.0
# 21/04/2023                       64.0                    2.0
# 22/04/2023                       64.0                   11.0
# 23/04/2023                       71.0                   13.0
#
#             3pm MSL pressure (hPa)  Total Demand   Price  Max Demand  \
# Date
# 01/11/2022                   991.5       4455.59   44.58     5627.52
# 02/11/2022                  1008.4       4472.30   -6.75     6018.43
# 03/11/2022                  1021.3       4661.52   59.99     6004.84
# 04/11/2022                  1026.6       4746.98  127.01     5757.62
# 05/11/2022                  1023.2       4593.25   93.98     4783.60
# ...                            ...           ...     ...         ...
# 19/04/2023                  1022.1       4432.95  101.00     6042.88
# 20/04/2023                  1025.5       4697.97  141.00     6084.21
# 21/04/2023                  1029.2       4667.72  103.26     5903.60
# 22/04/2023                  1029.7       4662.14  135.86     5313.61
# 23/04/2023                  1032.4       4498.73   75.00     5361.47
#
#             Max Price
# Date
# 01/11/2022      84.06
# 02/11/2022     112.30
# 03/11/2022     299.50
# 04/11/2022     276.70
# 05/11/2022     268.47
# ...               ...
# 19/04/2023     299.50
# 20/04/2023     349.33
# 21/04/2023     309.23
# 22/04/2023     141.00
# 23/04/2023     285.16
#
# [174 rows x 16 columns]

# %%
# CHECKING INTEGRITY OF NEW DATASET

index_counts = price_and_demand_new.index.value_counts()
print(index_counts)
# Out:
# Date
# 01/11/2022    1
# 28/02/2023    1
# 20/02/2023    1
# 21/02/2023    1
# 22/02/2023    1
#              ..
# 30/12/2022    1
# 31/12/2022    1
# 01/01/2023    1
# 02/01/2023    1
# 23/04/2023    1
# Name: count, Length: 174, dtype: int64

# %%
# CHECK FOR MISSING COLUMN VALUES
df.isna().sum()
# Out:
# Minimum temperature (°C)             0
# Maximum temperature (°C)             0
# Rainfall (mm)                        0
# Speed of maximum wind gust (km/h)    0
# 9am Temperature (°C)                 0
# 9am relative humidity (%)            0
# 9am wind speed (km/h)                0
# 9am MSL pressure (hPa)               0
# 3pm Temperature (°C)                 0
# 3pm relative humidity (%)            0
# 3pm wind speed (km/h)                0
# 3pm MSL pressure (hPa)               0
# Total Demand                         0
# Price                                0
# Max Demand                           0
# Max Price                            0
# dtype: int64

# %%
# CHECK DATA TYPES
df.dtypes
# Out:
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Speed of maximum wind gust (km/h)    float64
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)              int64
# 9am wind speed (km/h)                  Int64
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)            float64
# 3pm wind speed (km/h)                float64
# 3pm MSL pressure (hPa)               float64
# Total Demand                         float64
# Price                                float64
# Max Demand                           float64
# Max Price                            float64
# dtype: object

# %%
display(df)
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 01/11/2022                       8.5                      13.3            3.0
# 02/11/2022                       6.9                      15.7            2.8
# 03/11/2022                       9.1                      15.4            0.4
# 04/11/2022                      10.2                      17.8            0.2
# 05/11/2022                      11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 19/04/2023                      14.4                      17.5            1.2
# 20/04/2023                       7.8                      18.5            0.0
# 21/04/2023                      11.3                      19.0            0.0
# 22/04/2023                      14.6                      19.2            0.0
# 23/04/2023                      14.8                      19.0            0.0
#
#             Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# Date
# 01/11/2022                               44.0                  12.0
# 02/11/2022                               43.0                  11.0
# 03/11/2022                               31.0                  11.5
# 04/11/2022                               24.0                  12.3
# 05/11/2022                               31.0                  14.0
# ...                                       ...                   ...
# 19/04/2023                               28.0                  14.8
# 20/04/2023                               17.0                  12.4
# 21/04/2023                               13.0                  14.8
# 22/04/2023                               22.0                  15.2
# 23/04/2023                               26.0                  16.7
#
#             9am relative humidity (%)  9am wind speed (km/h)  \
# Date
# 01/11/2022                         64                     13
# 02/11/2022                         65                      9
# 03/11/2022                         70                      9
# 04/11/2022                         84                      6
# 05/11/2022                         78                      9
# ...                               ...                    ...
# 19/04/2023                         66                      9
# 20/04/2023                         72                      7
# 21/04/2023                         78                      6
# 22/04/2023                         84                      6
# 23/04/2023                         79                      7
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 01/11/2022                   991.3                  13.2
# 02/11/2022                  1006.7                  15.1
# 03/11/2022                  1019.2                  13.8
# 04/11/2022                  1028.1                  16.9
# 05/11/2022                  1026.3                  18.8
# ...                            ...                   ...
# 19/04/2023                  1022.0                  15.8
# 20/04/2023                  1026.8                  17.5
# 21/04/2023                  1030.5                  18.6
# 22/04/2023                  1031.9                  18.8
# 23/04/2023                  1034.4                  17.8
#
#             3pm relative humidity (%)  3pm wind speed (km/h)  \
# Date
# 01/11/2022                       59.0                   11.0
# 02/11/2022                       54.0                   13.0
# 03/11/2022                       67.0                    9.0
# 04/11/2022                       56.0                    9.0
# 05/11/2022                       65.0                   11.0
# ...                               ...                    ...
# 19/04/2023                       53.0                    9.0
# 20/04/2023                       58.0                    4.0
# 21/04/2023                       64.0                    2.0
# 22/04/2023                       64.0                   11.0
# 23/04/2023                       71.0                   13.0
#
#             3pm MSL pressure (hPa)  Total Demand   Price  Max Demand  \
# Date
# 01/11/2022                   991.5       4455.59   44.58     5627.52
# 02/11/2022                  1008.4       4472.30   -6.75     6018.43
# 03/11/2022                  1021.3       4661.52   59.99     6004.84
# 04/11/2022                  1026.6       4746.98  127.01     5757.62
# 05/11/2022                  1023.2       4593.25   93.98     4783.60
# ...                            ...           ...     ...         ...
# 19/04/2023                  1022.1       4432.95  101.00     6042.88
# 20/04/2023                  1025.5       4697.97  141.00     6084.21
# 21/04/2023                  1029.2       4667.72  103.26     5903.60
# 22/04/2023                  1029.7       4662.14  135.86     5313.61
# 23/04/2023                  1032.4       4498.73   75.00     5361.47
#
#             Max Price
# Date
# 01/11/2022      84.06
# 02/11/2022     112.30
# 03/11/2022     299.50
# 04/11/2022     276.70
# 05/11/2022     268.47
# ...               ...
# 19/04/2023     299.50
# 20/04/2023     349.33
# 21/04/2023     309.23
# 22/04/2023     141.00
# 23/04/2023     285.16
#
# [174 rows x 16 columns]

# %%
# CORRELATION AND MUTUAL INFORMATION

# %%
# Scatter Plot of Min Temp and Max Demand
plt.scatter(df['Minimum temperature (°C)'],df['Max Demand'])
plt.show()
# Appears to be some sort of weak positive correlation

#Pearson's r
print("Pearson r is ",df['Minimum temperature (°C)'].corr(df['Max Demand']))
# Out:
# Pearson r is  0.2791754924411037

# %%
# Scatter Plot of Max Temp and Max Demand
plt.scatter(df['Maximum temperature (°C)'],df['Max Demand'])
plt.show()
# Appears to be some sort of positive correlation

#Pearson's r
print("Pearson r is ",df['Maximum temperature (°C)'].corr(df['Max Demand']))
# Out:
# Pearson r is  0.6005105111350008

# %%
# Scatter Plot of Rainfall and Max Demand
plt.scatter(df['Rainfall (mm)'],df['Max Demand'])
plt.show()
# Appears to be no correlation

#Pearson's r
print("Pearson r is ",df['Rainfall (mm)'].corr(df['Max Demand']))
# Out:
# Pearson r is  -0.09301618831135618

# %%
# Scatter Plot of Speed of maximum wind gust (km/h) and Max Demand
plt.scatter(df['Speed of maximum wind gust (km/h)'],df['Max Demand'])
plt.show()
# Appears to be some sort of positive correlation

# %%
# Scatter Plot of 9am Temperature (°C) and Max Demand
plt.scatter(df['9am Temperature (°C)'],df['Max Demand'])
plt.show()
# Appears to be none or extremely weak negative correlation

#Pearson's r
print("Pearson r is ",df['9am Temperature (°C)'].corr(df['Max Demand']))
# Out:
# Pearson r is  0.4464512720488092

# %%
# Scatter Plot of 9am relative humidity (%) and Max Demand
plt.scatter(df['9am relative humidity (%)'],df['Max Demand'])
plt.show()
# Appears to be some sort of weak positive correlation / non-linear

#Pearson's r
print("Pearson r is ",df['9am relative humidity (%)'].corr(df['Max Demand']))
# Out:
# Pearson r is  -0.14576197396626223

# %%
# Scatter Plot of 9am wind speed (km/h) and Max Demand
plt.scatter(df['9am wind speed (km/h)'],df['Max Demand'])
plt.show()
# Appears to be no correlation or extemely weak 

print(df.dtypes)
print(df.isnull().sum())

#Pearson's r
# GETTING AN ERROR FOR PEARSON'S - ITS BECAUSE OF VALUES OF 0 in the 9am Wind Speed Col - not correlated so don't bother
# print("Pearson r is ",df['9am wind speed (km/h)'].corr(df['Max Demand']))
# Out:
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Speed of maximum wind gust (km/h)    float64
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)              int64
# 9am wind speed (km/h)                  Int64
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)            float64
# 3pm wind speed (km/h)                float64
# 3pm MSL pressure (hPa)               float64
# Total Demand                         float64
# Price                                float64
# Max Demand                           float64
# Max Price                            float64
# dtype: object
# Minimum temperature (°C)             0
# Maximum temperature (°C)             0
# Rainfall (mm)                        0
# Speed of maximum wind gust (km/h)    0
# 9am Temperature (°C)                 0
# 9am relative humidity (%)            0
# 9am wind speed (km/h)                0
# 9am MSL pressure (hPa)               0
# 3pm Temperature (°C)                 0
# 3pm relative humidity (%)            0
# 3pm wind speed (km/h)                0
# 3pm MSL pressure (hPa)               0
# Total Demand                         0
# Price                                0
# Max Demand                           0
# Max Price                            0
# dtype: int64

# %%
# Scatter Plot of 9am MSL pressure (hPa) and Max Demand
plt.scatter(df['9am MSL pressure (hPa)'],df['Max Demand'])
plt.show()
# Appears to be no correlation

#Pearson's r
print("Pearson r is ",df['9am MSL pressure (hPa)'].corr(df['Max Demand']))
# Out:
# Pearson r is  0.03940574389127598

# %%
# Scatter Plot of 3pm Temperature (°C) and Max Demand
plt.scatter(df['3pm Temperature (°C)'],df['Max Demand'])
plt.show()
# Appears to be no correlation

#Pearson's r
print("Pearson r is ",df['3pm Temperature (°C)'].corr(df['Max Demand']))
#Moderate positive correlation
# Out:
# Pearson r is  0.6047938028733985

# %%
# Scatter Plot of 3pm relative humidity (%) and Max Demand
plt.scatter(df['3pm relative humidity (%)'],df['Max Demand'])
plt.show()
# Appears to be some sort of negative correlation (lower humidity means higher demand) but only towards the low range

#Pearson's r
print("Pearson r is ",df['3pm relative humidity (%)'].corr(df['Max Demand']))
#Moderately negatively correlated
#When there is very low wind, there is very high energy demand - could be non-linear?
# Out:
# Pearson r is  -0.3553343509062848

# %%
# Scatter Plot of 3pm wind speed (km/h) and Max Demand
plt.scatter(df['3pm wind speed (km/h)'],df['Max Demand'])
plt.show()
# Appears to be some sort of positive correlation

# %%
# Scatter Plot of 3pm MSL pressure (hPa) and Max Demand
plt.scatter(df['3pm MSL pressure (hPa)'],df['Max Demand'])
plt.show()
# Appears to be no correlation

#Pearson's r
print("Pearson r is ",df['3pm MSL pressure (hPa)'].corr(df['Max Demand']))
#Moderate positive correlation
# Out:
# Pearson r is  -0.04181767894437309

# %%
# Scatter Plot of Price and Max Demand
plt.scatter(df['Price'],df['Max Demand'])
plt.show()
# Appears to be no correlation 

#Pearson's r
print("Pearson r is ",df['Price'].corr(df['Max Demand']))
#Very weak correlation
# Out:
# Pearson r is  0.1424522597151014

# %%
# Scatter Plot of Max Price and Max Demand
plt.scatter(df['Max Price'],df['Max Demand'])
plt.show()
# Appears to be some sort of positive correlation

#Pearson's r
print("Pearson r is ",df['Max Price'].corr(df['Max Demand']))
#Weak correlation, and the variables are definitely related
# Out:
# Pearson r is  0.3611853682188425

# %%
# THE FEATURES MOST HIGHLY CORRELATED WITH MAXIMUM DEMAND ARE:

# 3pm Temperature (°C):        0.61
# Maximum temperature (°C):    0.60
# 9am Temperature (°C):        0.45
# 3pm relative humidity (%):  -0.36
# Minimum temperature (°C)     0.28
